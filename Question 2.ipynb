# %% [markdown]
# # Which of the following is not a valid Python variable name?
# # a) my_variable
# # b) _my_variable
# # c) 3myvariable
# # d) MY_VARIABLE

# %%
Ans = ''' 3myvariable '''
print(Ans)
# Out:
#  3myvariable
