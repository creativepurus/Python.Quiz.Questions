# %% [markdown]
# # What is the output of the following code snippet?

# %%
x = 10
y = 5
result = x % y
print(result)

# %% [markdown]
# a) 0
#
# b) 1
#
# c) 2
#
# d) 5

# %% [markdown]
# # Below is the answer :

# %%
x = 10
y = 5
result = x % y
print(result)
# Out:
# 0
