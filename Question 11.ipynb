# %% [markdown]
# # What will be the output of the following code ?

# %%
my_string = "Hello, World!"
print(len(my_string))

# %% [markdown]
# # a) 5
# # b) 12
# # c) 13
# # d) 14

# %% [markdown]
# # Below is the answer :

# %%
my_string = "Hello, World!"
print(len(my_string))
# Out:
# 13
