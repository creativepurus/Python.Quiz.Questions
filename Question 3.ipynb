# %% [markdown]
# # What will be the output of the following code snippet?

# %%
my_list = [1, 2, 3, 4, 5]
print(my_list[1:4])

# %% [markdown]
# a) [1, 2, 3]
#
# b) [2, 3, 4]
#
# c) [1, 2, 3, 4]
#
# d) [2, 3, 4, 5]

# %% [markdown]
# # Below is the answer :

# %%
my_list = [1, 2, 3, 4, 5]
print(my_list[1:4])
# Out:
# [2, 3, 4]
